# %%
import ast
import numpy as np
import os
import sys
os.chdir('C:/Users/dimo/Desktop/code-mo-test/comocma/')
sys.path.insert(0, '.')
import como
# %matplotlib nbagg
from matplotlib import pyplot as plt
import matplotlib

# %%
idsofrestarts = ast.literal_eval(open('onlyrandom-idsofrestarts.tmp', 'r').read()) 
bestchvs = ast.literal_eval(open('onlyrandom-bestchvsatrestart.tmp', 'r').read()) 

plt.figure(27)
plt.plot(idsofrestarts, 'x', label='ids of restarted kernels')
#plt.plot(bestchvs, 'x', label='best chv of kernels at restart')
plt.xlabel('number of kernels')
plt.ylabel('ids and best chv of restarted kernels\n (nothing shown for random restarts)')
matplotlib.pyplot.grid(True, which="both")

# %%
countiters = ast.literal_eval(open('onlyrandom-countiters.tmp', 'r').read()) 

plt.figure(3)
plt.semilogy(countiters, '-', label='countiters')
plt.legend()
plt.xlabel('number of kernels')
plt.ylabel('countiters for each kernel')
matplotlib.pyplot.grid(True, which="both")

# %%
seedsatrestart = ast.literal_eval(open('onlyrandom-seedsatrestart.tmp', 'r').read()) 
print(seedsatrestart)
# Out:
# [821402, 773486, 822659, 830563, 751006, 766097, 844170, 703433, 739426, 821268, 818637, 751056, 757026, 807693, 776285, 804275, 841203, 725811, 704694, 694617, 787384, 717817, 760904, 688850, 780767, 679732, 748007, 796255, 780303, 761294, 774990, 807371, 776438, 853798, 834966, 680188, 709913, 798037, 720402, 746534, 789508, 706157, 746642, 743380, 777973, 767540, 784235, 813676, 702399, 685124, 723106, 729552, 753790, 774812, 740956, 750264, 776039, 744696, 688393, 728415, 793203, 803901, 721864, 795840]

# %%
import numpy as np
np.random.seed(20000)
for _ in range(4):
    print(np.random.get_state()[1][0])
    print(np.random.rand(2))
print('++++++++++')    
np.random.seed(30000)
for _ in range(4):
    print(np.random.get_state()[1][0])
    print(np.random.rand(2))
# Out:
# 20000
# [0.39292425 0.86143884]
# 3080851703
# [0.27614608 0.18111483]
# 3080851703
# [0.07707312 0.78397184]
# 3080851703
# [0.36196641 0.42600612]
# ++++++++++
# 30000
# [0.51037324 0.63566456]
# 4294330951
# [0.16437413 0.26443771]
# 4294330951
# [0.19426605 0.12709674]
# 4294330951
# [0.71877634 0.58675509]
