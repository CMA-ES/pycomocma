# %%
import cma

# %%
es = cma.CMAEvolutionStrategy(10 * [1], 0.2)
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1103738, Wed Aug 28 15:07:20 2019)

# %%
while not es.stop():
    solutions = es.ask()
    objective_values = [cma.ff.sphere(x) for x in solutions]
    es.tell(solutions, objective_values)
    es.disp()
    es.logger.add()
# Out:
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 9.232066245795592e+00 1.0e+00 1.96e-01  2e-01  2e-01 0:00.0
#     2     20 8.433742724692939e+00 1.2e+00 2.00e-01  2e-01  2e-01 0:00.0
#     3     30 8.105272238928217e+00 1.3e+00 2.12e-01  2e-01  2e-01 0:00.0
#   100   1000 6.061156999900649e-06 1.9e+00 1.96e-03  8e-04  1e-03 0:00.1
#   200   2000 6.692430885879211e-13 1.8e+00 2.10e-06  3e-07  4e-07 0:00.2
#   224   2240 1.973754949335874e-14 2.0e+00 4.34e-07  6e-08  7e-08 0:00.2

# %%
es.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
es.logger?

# %%
es.logger

# %%
# %pylab nbagg
# %matplotlib notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Warning: Cannot change to a different GUI toolkit: notebook. Using nbagg instead.

# %%
cma.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import cma, mo, pickle

# Set parameters
dimension = 10
num_kernels = 5

# Instantiating `Sofomore` with `cma-es`, via the `get_cmas` factory function:

list_of_solvers = mo.get_cmas(num_kernels * [dimension * [0.3]], 0.2)
moes = mo.Sofomore(list_of_solvers, reference_point = [11,11])

# %%
#while not moes.stop():
fitness = mo.FitFun(cma.ff.sphere, lambda x: cma.ff.sphere(x-1))
for i in range(100):
    solutions = moes.ask()
    objective_values = [fitness(x) for x in solutions]
    moes.tell(solutions, objective_values)
    moes.disp()
  #  moes.logger.add()
# Out:
# Iterat #Fevals   Hypervolume   axis ratios   sigmas   min&max stds
#                                   (median)  (median)    (median)
#     1     10 6.161000000000001e+01 1.0e+00 2.00e-01  2e-01  2e-01
#     2     20 6.578504775953337e+01 1.0e+00 2.00e-01  2e-01  2e-01
#     3     30 6.777281084918566e+01 1.0e+00 1.89e-01  2e-01  2e-01
#   100   1000 9.653227459940996e+01 1.6e+00 9.77e-02  7e-02  1e-01
