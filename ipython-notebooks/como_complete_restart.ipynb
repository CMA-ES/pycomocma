# %%
# %pylab nbagg
import cma, como
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dimension = 10
num_kernels = 10 # number of single-objective solvers (population size)

# %%
refpoint = [11, 11]
sigma0 = 0.2
fun1 = cma.ff.sphere
fun2 = lambda x: cma.ff.sphere(x-1)
fun = como.FitFun(fun1, fun2)

# %%
list_of_solvers = como.get_cmas(-5 + 10 * np.random.rand(num_kernels, dimension), sigma0, inopts={'popsize':32}) # produce `num_kernels cma instances`
moes = como.Sofomore(list_of_solvers, opts = {'archive': True}, reference_point = refpoint) # create a como-cma-es instance

# %%
while not moes.stop():
    X = moes.ask()
    values = [fun(x) for x in X]
    moes.tell(X, values)

# %%
moes.logger.plot_front()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import cma

# %%
import cma
es = cma.CMAEvolutionStrategy(np.array([1]), 0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-3e4b566c55fa> in <module>
#       1 import cma
# ----> 2 es = cma.CMAEvolutionStrategy(np.array([1]), 0.2)
#
# ~/Downloads/______phD/code-mo/python/cma/evolution_strategy.py in __init__(self, x0, sigma0, inopts)
#    1350             raise ValueError('restarts not available with class CMAEvolutionStrategy, use function fmin')
#    1351
# -> 1352         self._set_x0(x0)  # manage weird shapes, set self.x0
#    1353         self.N_pheno = len(self.x0)
#    1354
#
# ~/Downloads/______phD/code-mo/python/cma/evolution_strategy.py in _set_x0(self, x0)
#    1702             raise ValueError('x0 must be 1-D array')
#    1703         if len(self.x0) <= 1:
# -> 1704             raise ValueError('optimization in 1-D is not supported (code was never tested)')
#    1705         try:
# ...

# %%
func = lambda x: -cma.ff.sphere(x)

# %%
es.optimize(func)
# Out:
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.232658775551287e+01 1.0e+00 1.95e-01  2e-01  2e-01 0:00.0
#     2     20 -1.401668765706582e+01 1.2e+00 2.08e-01  2e-01  2e-01 0:00.0
#     3     30 -1.540729775878266e+01 1.4e+00 2.27e-01  2e-01  3e-01 0:00.0
#    40    400 -2.988122601195900e+06 2.1e+00 2.24e+02  2e+02  2e+02 0:00.0

# %%
es.mean
# Out:
# array([  435.83854651,   195.2875126 ,   607.50387046,  -188.26423914,
#          575.24705735,  -233.30339175,  -108.73848804,  -213.96131764,
#          601.64456648, -1034.93621229])

# %%
func(es.mean)
# Out:
# -2508609.129265982

# %%
es.logger.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
