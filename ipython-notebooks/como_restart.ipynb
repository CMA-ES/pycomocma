# %%
# %pylab nbagg
import cma, como
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dimension = 10
num_kernels = 1 # number of single-objective solvers (population size)

# %%
refpoint = [11, 11]
sigma0 = 0.2
fun1 = cma.ff.sphere
fun2 = lambda x: cma.ff.sphere(x-1)
fitness = como.FitFun(fun1, fun2)

# %%
list_of_solvers = como.get_cmas(-5 + 10 * np.random.rand(num_kernels, dimension), sigma0) # produce `num_kernels cma instances`
moes = como.Sofomore(list_of_solvers, opts = {'archive': True, 'restart': [-5, 5]}, reference_point = refpoint) # create a como-cma-es instance
#moes = como.Sofomore(list_of_solvers, opts = {'archive': True}, reference_point = refpoint) # create a como-cma-es instance

# %%
moes.optimize(fitness, iterations=5000)
# Out:
# Iterat #Fevals   Hypervolume   axis ratios   sigmas   min&max stds
#                                   (median)  (median)    (median)
#     1     10 0.000000000000000e+00 1.0e+00 1.94e-01  2e-01  2e-01
#     2     20 0.000000000000000e+00 1.2e+00 2.06e-01  2e-01  2e-01
#     3     30 0.000000000000000e+00 1.4e+00 2.17e-01  2e-01  2e-01
#   100   1000 7.224977330632650e+01 1.8e+00 4.30e-03  2e-03  2e-03
#   200   2000 8.187329538929740e+01 1.9e+00 9.56e-02  6e-02  7e-02
#   300   3000 8.233056722964695e+01 1.8e+00 2.84e-04  8e-05  1e-04
#   400   4000 9.241111078575534e+01 1.8e+00 2.84e-04  8e-05  1e-04
#   500   5000 9.241153117424774e+01 2.0e+00 3.09e-04  8e-05  1e-04
#   600   6000 9.422572282723029e+01 2.0e+00 3.09e-04  8e-05  1e-04
#   700   7000 9.599987687525046e+01 2.1e+00 2.85e-04  8e-05  1e-04
#   800   8000 9.603969493004797e+01 2.1e+00 2.84e-04  7e-05  1e-04
#   900   9000 9.767814975081561e+01 2.0e+00 2.84e-04  7e-05  1e-04
# ...

# %%
figure()
tab1 = [kernel.objective_values[0] for kernel in moes.kernels]
tab2 = [kernel.objective_values[1] for kernel in moes.kernels]
tab11 = [moes.kernels[i].objective_values[0] for i in moes._active_indices]
tab22 = [moes.kernels[i].objective_values[1] for i in moes._active_indices]
plt.plot(tab1,  tab2, 'o')
moes.logger.plot_front()
plt.plot(tab11,  tab22, 'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
tab1 = [kernel.objective_values[0] for kernel in moes.kernels]
tab2 = [kernel.objective_values[1] for kernel in moes.kernels]
tab11 = [moes.kernels[i].objective_values[0] for i in moes._active_indices]
tab22 = [moes.kernels[i].objective_values[1] for i in moes._active_indices]
plt.plot(tab1,  tab2, 'o')
moes.logger.plot_front()
plt.plot(tab11,  tab22, 'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %pylab nbagg
import cma, como
import numpy as np

# %%
dimension = 10
num_kernels = 5 # number of single-objective solvers (population size)

# %%
refpoint = [110, 110]
sigma0 = 5
fun1 = lambda x: sum(np.abs(x)**0.8 + 5 * np.sin(x**3))
fun2 = lambda x: (10. * len(x) + sum( x**2 -10. * np.cos(2. * np.pi * x)))/5 #rastrigin
fitness = como.FitFun(fun1, fun2)

# %%
list_of_solvers = como.get_cmas(-5 + 10 * np.random.rand(num_kernels, dimension), sigma0, inopts={'tolx':10**-7}) # produce `num_kernels cma instances`
moes = como.Sofomore(list_of_solvers, opts = {'archive': True, 'restart': None, 'update_order': None}, reference_point = refpoint) # create a como-cma-es instance

# %%
moes.optimize(fitness, iterations=2000)

# %%
figure()
tab1 = [kernel.objective_values[0] for kernel in moes.kernels]
tab2 = [kernel.objective_values[1] for kernel in moes.kernels]
tab11 = [moes.kernels[i].objective_values[0] for i in moes._active_indices]
tab22 = [moes.kernels[i].objective_values[1] for i in moes._active_indices]
plt.plot(tab1,  tab2, 'o')
moes.logger.plot_front()
plt.plot(tab11,  tab22, 'ro')

# %%
figure()
tab1 = [kernel.objective_values[0] for kernel in moes.kernels]
tab2 = [kernel.objective_values[1] for kernel in moes.kernels]
tab11 = [moes.kernels[i].objective_values[0] for i in moes._active_indices]
tab22 = [moes.kernels[i].objective_values[1] for i in moes._active_indices]
plt.plot(tab1,  tab2, 'o')
moes.logger.plot_front()
plt.plot(tab11,  tab22, 'ro')

# %%
moes._active_indices

# %%
moes.kernels[2].incumbent

# %%
fun1 = lambda x: sum(np.abs(x)**0.8 + 5 * np.sin(x**3))
fun2 = lambda x: (10. * len(x) + sum( x**2 -10. * np.cos(2. * np.pi * x)))/5 #rastrigin

# %%
import cma
import numpy as np

# %%
es = cma.CMAEvolutionStrategy(100*np.random.rand(5), 10, inopts={'tolx':10**-12})

# %%
es.optimize(fun1, iterations = 200)

# %%
es.logger.plot()

# %%
es.x0

# %%
es.best.x

# %%
es.best.f

# %%
es.best.x

# %%
es.best.f

# %%
es.stop()

# %%
es = cma.CMAEvolutionStrategy(11*[0], sigma0=0.3)

# %%
es = cma.CMAEvolutionStrategy(11 * [0], 0.2)

# %%
es.best

# %%
type(es.best.x)
